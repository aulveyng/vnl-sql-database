# %%
import os
import pandas as pd
import psycopg2

from dotenv import load_dotenv


# Load environment variables
load_dotenv()


# Database connection
connection = psycopg2.connect(
    host=os.getenv("DB_HOST"),
    port=os.getenv("DB_PORT"),
    dbname=os.getenv("DB_NAME"),
    user=os.getenv("DB_USER"),
    password=os.getenv("DB_PASSWORD"),
    sslmode="require"
)


# SQL query
query = """
SELECT *
FROM ml_training_data
ORDER BY match_date, match_id;
"""


# Load data into Pandas
df = pd.read_sql_query(query, connection)


# Close database connection
connection.close()


# Display information
print("Data successfully loaded!")
print()

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print()

print(df.head())

print(df.info())
print(df.isnull().sum())

features = [
    "win_rate_diff",
    "attack_efficiency_diff",
    "serve_efficiency_diff",
    "serve_aces_diff",
    "serve_errors_diff",
    "reception_positive_diff",
    "reception_perfect_diff",
    "block_points_diff",
    "digs_diff",
    "assists_diff"
]

X = df[features]
y = df["target"]

print(y.value_counts())

print(df["week"].value_counts().sort_index())

train_df = df[df["week"] < 3]
test_df = df[df["week"] == 3]

print(df["week"].unique())

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print(df["week"].value_counts().sort_index())
print(df.isnull().sum())
print(y.value_counts())
# Out:
# C:\Users\aulve\AppData\Local\Temp\ipykernel_24136\1005473150.py:32: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
# Data successfully loaded!
#
# Rows: 63
# Columns: 30
#
#    match_id  week  match_date  team_a  team_b  target  \
# 0        10     1  2026-06-11       6      17       0
# 1        11     1  2026-06-11      15      13       1
# 2        12     1  2026-06-12       4      10       1
# 3        13     1  2026-06-12       9      11       0
# 4        14     1  2026-06-12       3       2       1
#
#    team_a_previous_matches  team_b_previous_matches  team_a_previous_wins  \
# 0                        1                        1                     0
# 1                        1                        1                     1
# 2                        1                        1                     0
# 3                        1                        1                     1
# 4                        1                        1                     1
#
#    team_b_previous_wins  ...  serve_errors_diff  serve_efficiency_diff  \
# 0                     0  ...                3.0                  -0.19
# 1                     1  ...                9.0                  -0.13
# 2                     0  ...                8.0                  -0.05
# 3                     0  ...               -4.0                  -0.05
# 4                     1  ...               -3.0                   0.00
#
#    reception_positive_diff  reception_perfect_diff  block_points_diff  \
# 0                     0.13                   -0.06                1.0
# 1                    -0.01                   -0.03                2.0
# 2                    -0.02                    0.01                3.0
# 3                    -0.01                    0.01               -3.0
# 4                     0.12                    0.00                7.0
#
#    block_touches_diff  digs_diff  assists_diff  points_diff  break_points_diff
# 0                 0.0       12.0          23.0         21.0                4.0
# 1                 2.0       11.0          27.0         24.0                5.0
# 2                 8.0       12.0           3.0          8.0                8.0
# 3                -2.0       -4.0           3.0         -6.0              -13.0
# 4                 4.0       -8.0           7.0         10.0                1.0
#
# [5 rows x 30 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   match_id                  63 non-null     int64
#  1   week                      63 non-null     int64
#  2   match_date                63 non-null     object
#  3   team_a                    63 non-null     int64
#  4   team_b                    63 non-null     int64
#  5   target                    63 non-null     int64
#  6   team_a_previous_matches   63 non-null     int64
#  7   team_b_previous_matches   63 non-null     int64
#  8   team_a_previous_wins      63 non-null     int64
#  9   team_b_previous_wins      63 non-null     int64
#  10  team_a_previous_losses    63 non-null     int64
#  11  team_b_previous_losses    63 non-null     int64
#  12  team_a_win_rate           63 non-null     float64
#  13  team_b_win_rate           63 non-null     float64
#  14  win_rate_diff             63 non-null     float64
#  15  team_a_attack_efficiency  63 non-null     float64
#  16  team_b_attack_efficiency  63 non-null     float64
#  17  attack_efficiency_diff    63 non-null     float64
#  18  attack_kills_diff         63 non-null     float64
#  19  serve_aces_diff           63 non-null     float64
#  20  serve_errors_diff         63 non-null     float64
#  21  serve_efficiency_diff     63 non-null     float64
#  22  reception_positive_diff   63 non-null     float64
#  23  reception_perfect_diff    63 non-null     float64
#  24  block_points_diff         63 non-null     float64
#  25  block_touches_diff        63 non-null     float64
#  26  digs_diff                 63 non-null     float64
#  27  assists_diff              63 non-null     float64
#  28  points_diff               63 non-null     float64
#  29  break_points_diff         63 non-null     float64
# dtypes: float64(18), int64(11), object(1)
# memory usage: 14.9+ KB
# None
# match_id                    0
# week                        0
# match_date                  0
# team_a                      0
# team_b                      0
# target                      0
# team_a_previous_matches     0
# team_b_previous_matches     0
# team_a_previous_wins        0
# team_b_previous_wins        0
# team_a_previous_losses      0
# team_b_previous_losses      0
# team_a_win_rate             0
# team_b_win_rate             0
# win_rate_diff               0
# team_a_attack_efficiency    0
# team_b_attack_efficiency    0
# attack_efficiency_diff      0
# attack_kills_diff           0
# serve_aces_diff             0
# serve_errors_diff           0
# serve_efficiency_diff       0
# reception_positive_diff     0
# reception_perfect_diff      0
# block_points_diff           0
# block_touches_diff          0
# digs_diff                   0
# assists_diff                0
# points_diff                 0
# break_points_diff           0
# dtype: int64
# target
# 0    33
# 1    30
# Name: count, dtype: int64
# week
# 1    27
# 2    36
# Name: count, dtype: int64
# [1 2]
# Rows: 63
# Columns: 30
# week
# 1    27
# 2    36
# Name: count, dtype: int64
# match_id                    0
# week                        0
# match_date                  0
# team_a                      0
# team_b                      0
# target                      0
# team_a_previous_matches     0
# team_b_previous_matches     0
# team_a_previous_wins        0
# team_b_previous_wins        0
# team_a_previous_losses      0
# team_b_previous_losses      0
# team_a_win_rate             0
# team_b_win_rate             0
# win_rate_diff               0
# team_a_attack_efficiency    0
# team_b_attack_efficiency    0
# attack_efficiency_diff      0
# attack_kills_diff           0
# serve_aces_diff             0
# serve_errors_diff           0
# serve_efficiency_diff       0
# reception_positive_diff     0
# reception_perfect_diff      0
# block_points_diff           0
# block_touches_diff          0
# digs_diff                   0
# assists_diff                0
# points_diff                 0
# break_points_diff           0
# dtype: int64
# target
# 0    33
# 1    30
# Name: count, dtype: int64
